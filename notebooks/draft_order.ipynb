# %%
import pandas as pd
import numpy as np

# %%
# 2024 draft order
draft_data_2024 = [
    [1, "Atlanta Hawks", "Zaccharie Risacher", ""],
    [2, "Washington Wizards", "Alex Sarr", ""],
    [3, "Houston Rockets", "Reed Sheppard", "Brooklyn Nets"],
    [4, "San Antonio Spurs", "Stephon Castle", ""],
    [5, "Detroit Pistons", "Ron Holland", ""],
    [6, "Charlotte Hornets", "Tidjane Salaun", ""],
    [7, "Portland Trail Blazers", "Donovan Clingan", ""],
    [8, "San Antonio Spurs", "Rob Dillingham", "Toronto Raptors"],
    [9, "Memphis Grizzlies", "Zach Edey", ""],
    [10, "Utah Jazz", "Cody Williams", ""],
    [11, "Chicago Bulls", "Matas Buzelis", ""],
    [12, "Oklahoma City Thunder", "Nikola Topic", "Houston Rockets"],
    [13, "Sacramento Kings", "Devin Carter", ""],
    [14, "Portland Trail Blazers", "Carlton Carrington", "Golden State Warriors"]
]

columns = ["pick", "team", "player", "acquired_from"]
draft_df_2024 = pd.DataFrame(draft_data_2024, columns=columns)
draft_df_2024.to_csv("../data/raw/2024/draft_2024.csv", index=False)

draft_df_2024
# Out:
#     pick                    team              player          acquired_from
# 0      1           Atlanta Hawks  Zaccharie Risacher
# 1      2      Washington Wizards           Alex Sarr
# 2      3         Houston Rockets       Reed Sheppard          Brooklyn Nets
# 3      4       San Antonio Spurs      Stephon Castle
# 4      5         Detroit Pistons         Ron Holland
# 5      6       Charlotte Hornets      Tidjane Salaun
# 6      7  Portland Trail Blazers     Donovan Clingan
# 7      8       San Antonio Spurs      Rob Dillingham        Toronto Raptors
# 8      9       Memphis Grizzlies           Zach Edey
# 9     10               Utah Jazz       Cody Williams
# 10    11           Chicago Bulls       Matas Buzelis
# 11    12   Oklahoma City Thunder        Nikola Topic        Houston Rockets
# 12    13        Sacramento Kings        Devin Carter
# 13    14  Portland Trail Blazers  Carlton Carrington  Golden State Warriors

# %%
# 2023 draft order
draft_data_2023 = [
    [1, "San Antonio Spurs", "Victor Wembanyama", ""],
    [2, "Charlotte Hornets", "Brandon Miller", ""],
    [3, "Portland Trail Blazers", "Scoot Henderson", ""],
    [4, "Houston Rockets", "Amen Thompson", ""],
    [5, "Detroit Pistons", "Ausar Thompson", ""],
    [6, "Orlando Magic", "Anthony Black", ""],
    [7, "Washington Wizards", "Bilal Coulibaly", "Indiana Pacers"],
    [8, "Indiana Pacers", "Jarace Walker", "Washington Wizards"],
    [9, "Utah Jazz", "Taylor Hendricks", ""],
    [10, "Oklahoma City Thunder", "Cason Wallace", "Dallas Mavericks"],
    [11, "Orlando Magic", "Jett Howard", ""],
    [12, "Dallas Mavericks", "Dereck Lively II", "Oklahoma City Thunder"],
    [13, "Toronto Raptors", "Gradey Dick", ""],
    [14, "New Orleans Pelicans", "Jordan Hawkins", ""]
]

draft_df_2023 = pd.DataFrame(draft_data_2023, columns=columns)
draft_df_2023.to_csv("../data/raw/2023/draft_2023.csv", index=False)

draft_df_2023
# Out:
#     pick                    team             player          acquired_from
# 0      1       San Antonio Spurs  Victor Wembanyama
# 1      2       Charlotte Hornets     Brandon Miller
# 2      3  Portland Trail Blazers    Scoot Henderson
# 3      4         Houston Rockets      Amen Thompson
# 4      5         Detroit Pistons     Ausar Thompson
# 5      6           Orlando Magic      Anthony Black
# 6      7      Washington Wizards    Bilal Coulibaly         Indiana Pacers
# 7      8          Indiana Pacers      Jarace Walker     Washington Wizards
# 8      9               Utah Jazz   Taylor Hendricks
# 9     10   Oklahoma City Thunder      Cason Wallace       Dallas Mavericks
# 10    11           Orlando Magic        Jett Howard
# 11    12        Dallas Mavericks   Dereck Lively II  Oklahoma City Thunder
# 12    13         Toronto Raptors        Gradey Dick
# 13    14    New Orleans Pelicans     Jordan Hawkins

# %%
# 2022 draft order
draft_data_2022 = [
    [1, "Orlando Magic", "Paolo Banchero", ""],
    [2, "Oklahoma City Thunder", "Chet Holmgren", ""],
    [3, "Houston Rockets", "Jabari Smith Jr.", ""],
    [4, "Sacramento Kings", "Keegan Murray", ""],
    [5, "Detroit Pistons", "Jaden Ivey", ""],
    [6, "Indiana Pacers", "Bennedict Mathurin", ""],
    [7, "Portland Trail Blazers", "Shaedon Sharpe", ""],
    [8, "New Orleans Pelicans", "Dyson Daniels", "Los Angeles Lakers"],
    [9, "San Antonio Spurs", "Jeremy Sochan", ""],
    [10, "Washington Wizards", "Johnny Davis", ""],
    [11, "Oklahoma City Thunder", "Ousmane Dieng", "New York Knicks"],  
    [12, "Oklahoma City Thunder", "Jalen Williams", "Los Angeles Clippers"],
    [13, "Detroit Pistons", "Jalen Duren", "Charlotte Hornets"],       
    [14, "Cleveland Cavaliers", "Ochai Agbaji", ""]
]

draft_df_2022 = pd.DataFrame(draft_data_2022, columns=columns)
draft_df_2022.to_csv("../data/raw/2022/draft_2022.csv", index=False)

draft_df_2022
# Out:
#     pick                    team              player         acquired_from
# 0      1           Orlando Magic      Paolo Banchero
# 1      2   Oklahoma City Thunder       Chet Holmgren
# 2      3         Houston Rockets    Jabari Smith Jr.
# 3      4        Sacramento Kings       Keegan Murray
# 4      5         Detroit Pistons          Jaden Ivey
# 5      6          Indiana Pacers  Bennedict Mathurin
# 6      7  Portland Trail Blazers      Shaedon Sharpe
# 7      8    New Orleans Pelicans       Dyson Daniels    Los Angeles Lakers
# 8      9       San Antonio Spurs       Jeremy Sochan
# 9     10      Washington Wizards        Johnny Davis
# 10    11   Oklahoma City Thunder       Ousmane Dieng       New York Knicks
# 11    12   Oklahoma City Thunder      Jalen Williams  Los Angeles Clippers
# 12    13         Detroit Pistons         Jalen Duren     Charlotte Hornets
# 13    14     Cleveland Cavaliers        Ochai Agbaji

# %%
# 2021 draft order
draft_data_2021 = [
    [1, "Detroit Pistons", "Cade Cunningham", ""],
    [2, "Houston Rockets", "Jalen Green", ""],
    [3, "Cleveland Cavaliers", "Evan Mobley", ""],
    [4, "Toronto Raptors", "Scottie Barnes", ""],
    [5, "Orlando Magic", "Jalen Suggs", ""],
    [6, "Oklahoma City Thunder", "Josh Giddey", ""],
    [7, "Golden State Warriors", "Jonathan Kuminga", "Minnesota Timberwolves"],
    [8, "Orlando Magic", "Franz Wagner", "Chicago Bulls"],
    [9, "Sacramento Kings", "Davion Mitchell", ""],
    [10, "Memphis Grizzlies", "Ziaire Williams", "New Orleans Pelicans"],
    [11, "Charlotte Hornets", "James Bouknight", ""],
    [12, "San Antonio Spurs", "Joshua Primo", ""],
    [13, "Indiana Pacers", "Chris Duarte", ""],
    [14, "Golden State Warriors", "Moses Moody", ""]
]

draft_df_2021 = pd.DataFrame(draft_data_2021, columns=columns)
draft_df_2021.to_csv("../data/raw/2021/draft_2021.csv", index=False)

draft_df_2021
# Out:
#     pick                   team            player           acquired_from
# 0      1        Detroit Pistons   Cade Cunningham
# 1      2        Houston Rockets       Jalen Green
# 2      3    Cleveland Cavaliers       Evan Mobley
# 3      4        Toronto Raptors    Scottie Barnes
# 4      5          Orlando Magic       Jalen Suggs
# 5      6  Oklahoma City Thunder       Josh Giddey
# 6      7  Golden State Warriors  Jonathan Kuminga  Minnesota Timberwolves
# 7      8          Orlando Magic      Franz Wagner           Chicago Bulls
# 8      9       Sacramento Kings   Davion Mitchell
# 9     10      Memphis Grizzlies   Ziaire Williams    New Orleans Pelicans
# 10    11      Charlotte Hornets   James Bouknight
# 11    12      San Antonio Spurs      Joshua Primo
# 12    13         Indiana Pacers      Chris Duarte
# 13    14  Golden State Warriors       Moses Moody

# %%
# 2020 draft order
draft_data_2020 = [
    [1, "Minnesota Timberwolves", "Anthony Edwards", ""],
    [2, "Golden State Warriors", "James Wiseman", ""],
    [3, "Charlotte Hornets", "LaMelo Ball", ""],
    [4, "Chicago Bulls", "Patrick Williams", ""],
    [5, "Cleveland Cavaliers", "Isaac Okoro", ""],
    [6, "Atlanta Hawks", "Onyeka Okongwu", ""],
    [7, "Detroit Pistons", "Killian Hayes", ""],
    [8, "New York Knicks", "Obi Toppin", ""],
    [9, "Washington Wizards", "Deni Avdija", ""],
    [10, "Phoenix Suns", "Jalen Smith", ""],
    [11, "San Antonio Spurs", "Devin Vassell", ""],
    [12, "Sacramento Kings", "Tyrese Haliburton", ""],
    [13, "New Orleans Pelicans", "Kira Lewis Jr.", ""],
    [14, "Boston Celtics", "Aaron Nesmith", "Memphis Grizzlies"]
]

draft_df_2020 = pd.DataFrame(draft_data_2020, columns=columns)
draft_df_2020.to_csv("../data/raw/2020/draft_2020.csv", index=False)

draft_df_2020
# Out:
#     pick                    team             player      acquired_from
# 0      1  Minnesota Timberwolves    Anthony Edwards
# 1      2   Golden State Warriors      James Wiseman
# 2      3       Charlotte Hornets        LaMelo Ball
# 3      4           Chicago Bulls   Patrick Williams
# 4      5     Cleveland Cavaliers        Isaac Okoro
# 5      6           Atlanta Hawks     Onyeka Okongwu
# 6      7         Detroit Pistons      Killian Hayes
# 7      8         New York Knicks         Obi Toppin
# 8      9      Washington Wizards        Deni Avdija
# 9     10            Phoenix Suns        Jalen Smith
# 10    11       San Antonio Spurs      Devin Vassell
# 11    12        Sacramento Kings  Tyrese Haliburton
# 12    13    New Orleans Pelicans     Kira Lewis Jr.
# 13    14          Boston Celtics      Aaron Nesmith  Memphis Grizzlies
